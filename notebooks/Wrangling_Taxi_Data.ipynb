# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd
import folium
import pickle

# %%
taxi_data = pd.read_csv('trip_data.csv')

# %%
taxi_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25           0.0
# 1         14.5    0.5      0.5        2.00           0.0
# 2          9.5    0.5      0.5        0.00           0.0
# 3          3.5    0.5      0.5        0.00           0.0
# 4         15.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %%
taxi_data[['tpep_pickup_datetime', 'tpep_dropoff_datetime']]
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime
# 0         2015-01-15 19:05:39   2015-01-15 19:23:42
# 1         2015-01-10 20:33:38   2015-01-10 20:53:28
# 2         2015-01-10 20:33:38   2015-01-10 20:43:41
# 3         2015-01-10 20:33:39   2015-01-10 20:35:31
# 4         2015-01-10 20:33:39   2015-01-10 20:52:58
# ...                       ...                   ...
# 12748981  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985  2015-01-10 19:01:45   2015-01-10 19:07:33
#
# [12748986 rows x 2 columns]

# %%
# Make time names more clear
taxi_data = taxi_data.rename(columns={
    'tpep_pickup_datetime': 'pickup_time',
    'tpep_dropoff_datetime': 'drop_off_time'
})

# %%
taxi_data
# Out:
#           VendorID          pickup_time        drop_off_time  passenger_count  \
# 0                2  2015-01-15 19:05:39  2015-01-15 19:23:42                1
# 1                1  2015-01-10 20:33:38  2015-01-10 20:53:28                1
# 2                1  2015-01-10 20:33:38  2015-01-10 20:43:41                1
# 3                1  2015-01-10 20:33:39  2015-01-10 20:35:31                1
# 4                1  2015-01-10 20:33:39  2015-01-10 20:52:58                1
# ...            ...                  ...                  ...              ...
# 12748981         1  2015-01-10 19:01:44  2015-01-10 19:05:40                2
# 12748982         1  2015-01-10 19:01:44  2015-01-10 19:07:26                2
# 12748983         1  2015-01-10 19:01:44  2015-01-10 19:15:01                1
# 12748984         1  2015-01-10 19:01:44  2015-01-10 19:17:03                1
# 12748985         1  2015-01-10 19:01:45  2015-01-10 19:07:33                1
#
#           trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0                  1.59        -73.993896        40.750111           1
# 1                  3.30        -74.001648        40.724243           1
# 2                  1.80        -73.963341        40.802788           1
# 3                  0.50        -74.009087        40.713818           1
# 4                  3.00        -73.971176        40.762428           1
# ...                 ...               ...              ...         ...
# 12748981           1.00        -73.951988        40.786217           1
# 12748982           0.80        -73.982742        40.728184           1
# 12748983           3.40        -73.979324        40.749550           1
# 12748984           1.30        -73.999565        40.738483           1
# 12748985           0.70        -73.960350        40.766399           1
#
#          store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                         N         -73.974785         40.750618
# 1                         N         -73.994415         40.759109
# 2                         N         -73.951820         40.824413
# 3                         N         -74.004326         40.719986
# 4                         N         -74.004181         40.742653
# ...                     ...                ...               ...
# 12748981                  N         -73.953735         40.775162
# 12748982                  N         -73.974976         40.720013
# 12748983                  N         -73.969101         40.787800
# 12748984                  N         -73.981819         40.737652
# 12748985                  N         -73.968643         40.760777
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    1         12.0    1.0      0.5        3.25           0.0
# 1                    1         14.5    0.5      0.5        2.00           0.0
# 2                    2          9.5    0.5      0.5        0.00           0.0
# 3                    2          3.5    0.5      0.5        0.00           0.0
# 4                    2         15.0    0.5      0.5        0.00           0.0
# ...                ...          ...    ...      ...         ...           ...
# 12748981             1          5.5    0.0      0.5        1.25           0.0
# 12748982             1          6.0    0.0      0.5        2.00           0.0
# 12748983             2         13.5    0.0      0.5        0.00           0.0
# 12748984             1         10.5    0.0      0.5        2.25           0.0
# 12748985             2          5.5    0.0      0.5        0.00           0.0
#
#           improvement_surcharge  total_amount
# 0                           0.3         17.05
# 1                           0.3         17.80
# 2                           0.3         10.80
# 3                           0.3          4.80
# 4                           0.3         16.30
# ...                         ...           ...
# 12748981                    0.3          7.55
# 12748982                    0.3          8.80
# 12748983                    0.3         14.30
# 12748984                    0.3         13.55
# 12748985                    0.3          6.30
#
# [12748986 rows x 19 columns]

# %%
# Convert columns to datetime format
taxi_data['pickup_time'] = pd.to_datetime(taxi_data['pickup_time'])
taxi_data['drop_off_time'] = pd.to_datetime(taxi_data['drop_off_time'])

# Display the data types to confirm the changes
taxi_data.dtypes
# Out:
# VendorID                          int64
# pickup_time              datetime64[ns]
# drop_off_time            datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# pickup_longitude                float64
# pickup_latitude                 float64
# RateCodeID                        int64
# store_and_fwd_flag               object
# dropoff_longitude               float64
# dropoff_latitude                float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
taxi_data['pickup_time']
# Out:
# 0          2015-01-15 19:05:39
# 1          2015-01-10 20:33:38
# 2          2015-01-10 20:33:38
# 3          2015-01-10 20:33:39
# 4          2015-01-10 20:33:39
#                    ...
# 12748981   2015-01-10 19:01:44
# 12748982   2015-01-10 19:01:44
# 12748983   2015-01-10 19:01:44
# 12748984   2015-01-10 19:01:44
# 12748985   2015-01-10 19:01:45
# Name: pickup_time, Length: 12748986, dtype: datetime64[ns]

# %%
taxi_data.isna().sum()
# Out:
# VendorID                 0
# pickup_time              0
# drop_off_time            0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    3
# total_amount             0
# dtype: int64

# %%
# Drop three duplcates
taxi_data.dropna()
# Out:
#           VendorID         pickup_time       drop_off_time  passenger_count  \
# 0                2 2015-01-15 19:05:39 2015-01-15 19:23:42                1
# 1                1 2015-01-10 20:33:38 2015-01-10 20:53:28                1
# 2                1 2015-01-10 20:33:38 2015-01-10 20:43:41                1
# 3                1 2015-01-10 20:33:39 2015-01-10 20:35:31                1
# 4                1 2015-01-10 20:33:39 2015-01-10 20:52:58                1
# ...            ...                 ...                 ...              ...
# 12748981         1 2015-01-10 19:01:44 2015-01-10 19:05:40                2
# 12748982         1 2015-01-10 19:01:44 2015-01-10 19:07:26                2
# 12748983         1 2015-01-10 19:01:44 2015-01-10 19:15:01                1
# 12748984         1 2015-01-10 19:01:44 2015-01-10 19:17:03                1
# 12748985         1 2015-01-10 19:01:45 2015-01-10 19:07:33                1
#
#           trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0                  1.59        -73.993896        40.750111           1
# 1                  3.30        -74.001648        40.724243           1
# 2                  1.80        -73.963341        40.802788           1
# 3                  0.50        -74.009087        40.713818           1
# 4                  3.00        -73.971176        40.762428           1
# ...                 ...               ...              ...         ...
# 12748981           1.00        -73.951988        40.786217           1
# 12748982           0.80        -73.982742        40.728184           1
# 12748983           3.40        -73.979324        40.749550           1
# 12748984           1.30        -73.999565        40.738483           1
# 12748985           0.70        -73.960350        40.766399           1
#
#          store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                         N         -73.974785         40.750618
# 1                         N         -73.994415         40.759109
# 2                         N         -73.951820         40.824413
# 3                         N         -74.004326         40.719986
# 4                         N         -74.004181         40.742653
# ...                     ...                ...               ...
# 12748981                  N         -73.953735         40.775162
# 12748982                  N         -73.974976         40.720013
# 12748983                  N         -73.969101         40.787800
# 12748984                  N         -73.981819         40.737652
# 12748985                  N         -73.968643         40.760777
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    1         12.0    1.0      0.5        3.25           0.0
# 1                    1         14.5    0.5      0.5        2.00           0.0
# 2                    2          9.5    0.5      0.5        0.00           0.0
# 3                    2          3.5    0.5      0.5        0.00           0.0
# 4                    2         15.0    0.5      0.5        0.00           0.0
# ...                ...          ...    ...      ...         ...           ...
# 12748981             1          5.5    0.0      0.5        1.25           0.0
# 12748982             1          6.0    0.0      0.5        2.00           0.0
# 12748983             2         13.5    0.0      0.5        0.00           0.0
# 12748984             1         10.5    0.0      0.5        2.25           0.0
# 12748985             2          5.5    0.0      0.5        0.00           0.0
#
#           improvement_surcharge  total_amount
# 0                           0.3         17.05
# 1                           0.3         17.80
# 2                           0.3         10.80
# 3                           0.3          4.80
# 4                           0.3         16.30
# ...                         ...           ...
# 12748981                    0.3          7.55
# 12748982                    0.3          8.80
# 12748983                    0.3         14.30
# 12748984                    0.3         13.55
# 12748985                    0.3          6.30
#
# [12748983 rows x 19 columns]

# %%
taxi_data.duplicated().sum()
# Out:
# 383

# %%
duplicate_rows = taxi_data[taxi_data.duplicated()]

# %% [markdown]
# ### These anamolies should be removed as they have no data worth keeping

# %%
duplicate_rows
# Out:
#           VendorID         pickup_time       drop_off_time  passenger_count  \
# 248333           2 2015-01-05 09:39:49 2015-01-05 09:39:52                1
# 248334           2 2015-01-05 09:39:49 2015-01-05 09:39:52                1
# 300143           2 2015-01-05 09:39:49 2015-01-05 09:39:52                1
# 300144           2 2015-01-05 09:39:49 2015-01-05 09:39:52                1
# 300145           2 2015-01-05 09:39:49 2015-01-05 09:39:52                1
# ...            ...                 ...                 ...              ...
# 12242582         2 2015-01-14 13:20:13 2015-01-14 13:20:33                1
# 12242583         2 2015-01-14 13:20:13 2015-01-14 13:20:33                1
# 12242584         2 2015-01-14 13:20:13 2015-01-14 13:20:33                1
# 12242585         2 2015-01-14 13:20:13 2015-01-14 13:20:33                1
# 12242586         2 2015-01-14 13:20:13 2015-01-14 13:20:33                1
#
#           trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 248333              0.0               0.0              0.0           1
# 248334              0.0               0.0              0.0           1
# 300143              0.0               0.0              0.0           1
# 300144              0.0               0.0              0.0           1
# 300145              0.0               0.0              0.0           1
# ...                 ...               ...              ...         ...
# 12242582            0.0               0.0              0.0           1
# 12242583            0.0               0.0              0.0           1
# 12242584            0.0               0.0              0.0           1
# 12242585            0.0               0.0              0.0           1
# 12242586            0.0               0.0              0.0           1
#
#          store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 248333                    N                0.0               0.0
# 248334                    N                0.0               0.0
# 300143                    N                0.0               0.0
# 300144                    N                0.0               0.0
# 300145                    N                0.0               0.0
# ...                     ...                ...               ...
# 12242582                  N                0.0               0.0
# 12242583                  N                0.0               0.0
# 12242584                  N                0.0               0.0
# 12242585                  N                0.0               0.0
# 12242586                  N                0.0               0.0
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 248333               2          2.5    0.0      0.5         0.0           0.0
# 248334               2          2.5    0.0      0.5         0.0           0.0
# 300143               2          2.5    0.0      0.5         0.0           0.0
# 300144               2          2.5    0.0      0.5         0.0           0.0
# 300145               2          2.5    0.0      0.5         0.0           0.0
# ...                ...          ...    ...      ...         ...           ...
# 12242582             2          2.0    0.0      0.5         0.0           0.0
# 12242583             2          2.0    0.0      0.5         0.0           0.0
# 12242584             2          2.0    0.0      0.5         0.0           0.0
# 12242585             2          2.0    0.0      0.5         0.0           0.0
# 12242586             2          2.0    0.0      0.5         0.0           0.0
#
#           improvement_surcharge  total_amount
# 248333                      0.3           3.3
# 248334                      0.3           3.3
# 300143                      0.3           3.3
# 300144                      0.3           3.3
# 300145                      0.3           3.3
# ...                         ...           ...
# 12242582                    0.3           2.8
# 12242583                    0.3           2.8
# 12242584                    0.3           2.8
# 12242585                    0.3           2.8
# 12242586                    0.3           2.8
#
# [383 rows x 19 columns]

# %%
taxi_data.drop_duplicates()
# Out:
#           VendorID         pickup_time       drop_off_time  passenger_count  \
# 0                2 2015-01-15 19:05:39 2015-01-15 19:23:42                1
# 1                1 2015-01-10 20:33:38 2015-01-10 20:53:28                1
# 2                1 2015-01-10 20:33:38 2015-01-10 20:43:41                1
# 3                1 2015-01-10 20:33:39 2015-01-10 20:35:31                1
# 4                1 2015-01-10 20:33:39 2015-01-10 20:52:58                1
# ...            ...                 ...                 ...              ...
# 12748981         1 2015-01-10 19:01:44 2015-01-10 19:05:40                2
# 12748982         1 2015-01-10 19:01:44 2015-01-10 19:07:26                2
# 12748983         1 2015-01-10 19:01:44 2015-01-10 19:15:01                1
# 12748984         1 2015-01-10 19:01:44 2015-01-10 19:17:03                1
# 12748985         1 2015-01-10 19:01:45 2015-01-10 19:07:33                1
#
#           trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0                  1.59        -73.993896        40.750111           1
# 1                  3.30        -74.001648        40.724243           1
# 2                  1.80        -73.963341        40.802788           1
# 3                  0.50        -74.009087        40.713818           1
# 4                  3.00        -73.971176        40.762428           1
# ...                 ...               ...              ...         ...
# 12748981           1.00        -73.951988        40.786217           1
# 12748982           0.80        -73.982742        40.728184           1
# 12748983           3.40        -73.979324        40.749550           1
# 12748984           1.30        -73.999565        40.738483           1
# 12748985           0.70        -73.960350        40.766399           1
#
#          store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                         N         -73.974785         40.750618
# 1                         N         -73.994415         40.759109
# 2                         N         -73.951820         40.824413
# 3                         N         -74.004326         40.719986
# 4                         N         -74.004181         40.742653
# ...                     ...                ...               ...
# 12748981                  N         -73.953735         40.775162
# 12748982                  N         -73.974976         40.720013
# 12748983                  N         -73.969101         40.787800
# 12748984                  N         -73.981819         40.737652
# 12748985                  N         -73.968643         40.760777
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    1         12.0    1.0      0.5        3.25           0.0
# 1                    1         14.5    0.5      0.5        2.00           0.0
# 2                    2          9.5    0.5      0.5        0.00           0.0
# 3                    2          3.5    0.5      0.5        0.00           0.0
# 4                    2         15.0    0.5      0.5        0.00           0.0
# ...                ...          ...    ...      ...         ...           ...
# 12748981             1          5.5    0.0      0.5        1.25           0.0
# 12748982             1          6.0    0.0      0.5        2.00           0.0
# 12748983             2         13.5    0.0      0.5        0.00           0.0
# 12748984             1         10.5    0.0      0.5        2.25           0.0
# 12748985             2          5.5    0.0      0.5        0.00           0.0
#
#           improvement_surcharge  total_amount
# 0                           0.3         17.05
# 1                           0.3         17.80
# 2                           0.3         10.80
# 3                           0.3          4.80
# 4                           0.3         16.30
# ...                         ...           ...
# 12748981                    0.3          7.55
# 12748982                    0.3          8.80
# 12748983                    0.3         14.30
# 12748984                    0.3         13.55
# 12748985                    0.3          6.30
#
# [12748603 rows x 19 columns]

# %%
# This column is irelevant
taxi_data.drop(columns=['store_and_fwd_flag'], inplace=True)

# %%
# Create trip duration column
taxi_data['Trip_Duration'] =  taxi_data['drop_off_time'] - taxi_data['pickup_time']

# %%
taxi_data['Trip_Duration'] = pd.to_timedelta(taxi_data['Trip_Duration'])
# Calculate total seconds
taxi_data['Total_Seconds'] = taxi_data['Trip_Duration'].dt.total_seconds()

# Convert seconds to minutes
taxi_data['Trip_Duration_in Minutes'] = taxi_data['Total_Seconds'] / 60

# Drop the 'Total Seconds' column if it's not needed
taxi_data = taxi_data.drop(columns=['Total_Seconds'])

# %%
# Duplicate Column removed
taxi_data.drop(columns=['Trip_Duration'], inplace=True)

# %%
# Mapping of numbers to payment method names
payment_method_mapping = {
    1: 'Credit card',
    2: 'Cash',
    3: 'No charge',
    4: 'Dispute',
    5: 'Unknown',
    6: 'Voided trip'
}

# Replace the numbers with the corresponding names
taxi_data['PaymentMethod'] = taxi_data['payment_type'].replace(payment_method_mapping)

# %%
taxi_data.head()
# Out:
#    VendorID         pickup_time       drop_off_time  passenger_count  \
# 0         2 2015-01-15 19:05:39 2015-01-15 19:23:42                1
# 1         1 2015-01-10 20:33:38 2015-01-10 20:53:28                1
# 2         1 2015-01-10 20:33:38 2015-01-10 20:43:41                1
# 3         1 2015-01-10 20:33:39 2015-01-10 20:35:31                1
# 4         1 2015-01-10 20:33:39 2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#    dropoff_longitude  dropoff_latitude  payment_type  fare_amount  extra  \
# 0         -73.974785         40.750618             1         12.0    1.0
# 1         -73.994415         40.759109             1         14.5    0.5
# 2         -73.951820         40.824413             2          9.5    0.5
# 3         -74.004326         40.719986             2          3.5    0.5
# 4         -74.004181         40.742653             2         15.0    0.5
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        3.25           0.0                    0.3         17.05
# 1      0.5        2.00           0.0                    0.3         17.80
# 2      0.5        0.00           0.0                    0.3         10.80
# 3      0.5        0.00           0.0                    0.3          4.80
# 4      0.5        0.00           0.0                    0.3         16.30
#
#    Trip_Duration_in Minutes PaymentMethod
# 0                 18.050000   Credit card
# 1                 19.833333   Credit card
# 2                 10.050000          Cash
# 3                  1.866667          Cash
# 4                 19.316667          Cash

# %%
taxi_data.to_pickle('wrangling_taxi.pkl')

# %%
taxi_data.to_csv('cleaned_taxi_data')
